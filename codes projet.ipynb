# %%
import pandas as pd

# %%
aeronefs= pd.read_parquet(r"C:\Users\andri\Documents\Wild Code School\Projet 3\aeronefs.parquet")
aeronefs

# %%
composants = pd.read_parquet(r'composants.parquet')
composants
# Out:
#                   ref_compo               categorie       aero  \
# 0       REAE175-E175_4124-0    Composants Critiques  E175_4124
# 1       REAE175-E175_4124-1    Composants Critiques  E175_4124
# 2       SYSE175-E175_4124-2    Composants Critiques  E175_4124
# 3       ORDE175-E175_4124-3    Composants Critiques  E175_4124
# 4       AUTE175-E175_4124-4    Composants Critiques  E175_4124
# ...                     ...                     ...        ...
# 10435  SYSB767-B767_6363-40  Composants Secondaires  B767_6363
# 10436  PORB767-B767_6363-41  Composants Secondaires  B767_6363
# 10437  HUBB767-B767_6363-42  Composants Secondaires  B767_6363
# 10438  ECLB767-B767_6363-43  Composants Secondaires  B767_6363
# 10439  SYSB767-B767_6363-44  Composants Secondaires  B767_6363
#
#                                      desc  lifespan  taux_usure_actuel   cout
# 0                         Réacteur gauche     11950          69.234150  19845
# ...

# %%
degradations = pd.read_parquet(r'C:\Users\andri\Documents\Wild Code School\Projet 3\degradations.parquet')
degradations
# Out:
#        ref_deg linked_aero       compo_concerned  usure_nouvelle measure_day  \
# 0      D002927   E175_4124   REAE175-E175_4124-0       69.234150  2023-11-06
# 1      D000558   E175_4124   REAE175-E175_4124-1       65.181958  2023-11-06
# 2      D001050   E175_4124   SYSE175-E175_4124-2       17.981443  2023-11-06
# 3      D007646   E175_4124   ORDE175-E175_4124-3       26.147164  2023-11-06
# 4      D006744   E175_4124   AUTE175-E175_4124-4       11.473035  2023-11-06
# ...        ...         ...                   ...             ...         ...
# 10525  D007824   B767_6363  SYSB767-B767_6363-40       26.476842  2023-11-07
# 10526  D006386   B767_6363  PORB767-B767_6363-41       19.875467  2023-11-07
# 10527  D006303   B767_6363  HUBB767-B767_6363-42       17.766530  2023-11-07
# 10528  D006123   B767_6363  ECLB767-B767_6363-43       28.869277  2023-11-07
# 10529  D002586   B767_6363  SYSB767-B767_6363-44       21.158927  2023-11-07
#
#        need_replacement
# ...

# %%
usure_maintenance = pd.merge(aeronefs, composants, how ='outer', left_on='ref_aero', right_on='aero')
usure_maintenance

# %%
evolution_mesures = pd.merge (usure_maintenance, degradations, how='outer', left_on='aero', right_on = 'linked_aero')
evolution_mesures
# Out:
#          ref_aero type_model debut_service           last_maint  \
# 0       A320_0691       A320    2018-07-11  2023-11-02 00:00:00
# 1       A320_0691       A320    2018-07-11  2023-11-02 00:00:00
# 2       A320_0691       A320    2018-07-11  2023-11-02 00:00:00
# 3       A320_0691       A320    2018-07-11  2023-11-02 00:00:00
# 4       A320_0691       A320    2018-07-11  2023-11-02 00:00:00
# ...           ...        ...           ...                  ...
# 498145  E175_6334       E175    2010-02-18  2023-11-01 00:00:00
# 498146  E175_6334       E175    2010-02-18  2023-11-01 00:00:00
# 498147  E175_6334       E175    2010-02-18  2023-11-01 00:00:00
# 498148  E175_6334       E175    2010-02-18  2023-11-01 00:00:00
# 498149  E175_6334       E175    2010-02-18  2023-11-01 00:00:00
#
#         en_maintenance            end_maint             ref_compo  \
# 0                False                 None   REAA320-A320_0691-0
# ...

# %%
log_vols = pd.read_parquet(r'C:\Users\andri\Documents\Wild Code School\Projet 3\log_vols.parquet')
log_vols
# Out:
#       ref_vol  aero_linked    jour_vol  time_en_air  \
# 0   V02208691    B777_5710  2023-11-07          2.7
# 1   V03716150  CRJ900_0709  2023-11-07          3.8
# 2   V03712533    A350_4582  2023-11-07          3.7
# 3   V06801291  CRJ700_2483  2023-11-07          5.8
# 4   V01739581    A380_1452  2023-11-07          7.8
# 5   V03886779    E170_5343  2023-11-07          4.1
# 6   V02858442    B767_1669  2023-11-07          8.3
# 7   V08192956  CRJ900_0692  2023-11-07          2.5
# 8   V01973109    B767_4568  2023-11-07          1.7
# 9   V08332258  CRJ900_3909  2023-11-07          2.7
# 10  V08064986    E170_3700  2023-11-07          5.9
# 11  V08943444    E175_3083  2023-11-07          2.4
# 12  V02155904    A330_5201  2023-11-07          4.3
# 13  V08235804    A380_4793  2023-11-07          2.0
# 14  V06344697    B747_2485  2023-11-07          8.3
# 15  V03694238    A350_6029  2023-11-07          4.2
# 16  V03479117    B777_2456  2023-11-07          5.8
# ...
